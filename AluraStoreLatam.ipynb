# %% [markdown]
# ### Importación de datos

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tienda.head()
# Out:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   8   4.60971 -74.08175
# 1  Tarjeta de crédito                   4   6.25184 -75.56359
# 2  Tarjeta de crédito                   1  10.39972 -75.51444
# 3               Nequi                   1   3.43722 -76.52250
# 4               Nequi                   1   6.25184 -75.56359

# %% [markdown]
# #Análisis de datos

# %%
#Ingreso total por cada tienda
ingresos_tienda1=tienda['Precio'].sum()
ingresos_tienda2=tienda2['Precio'].sum()
ingresos_tienda3=tienda3['Precio'].sum()
ingresos_tienda4=tienda4['Precio'].sum()

# %%
#cantidad de productos vendidos por categoria
productos_por_categoria1=tienda.groupby('Categoría del Producto')['Producto'].count()
productos_por_categoria2=tienda2.groupby('Categoría del Producto')['Producto'].count()
productos_por_categoria3=tienda3.groupby('Categoría del Producto')['Producto'].count()
productos_por_categoria4=tienda4.groupby('Categoría del Producto')['Producto'].count()

# %%
#Valoración media por tienda
valoracion_media_tienda1=tienda['Calificación'].mean()
valoracion_media_tienda2=tienda2['Calificación'].mean()
valoracion_media_tienda3=tienda3['Calificación'].mean()
valoracion_media_tienda4=tienda4['Calificación'].mean()

# %%
#Productos más vendidos y menos vendidos
productos_vendidos_tienda1={"Mas vendido":tienda['Producto'].value_counts().idxmax(),"Menos vendido":tienda['Producto'].value_counts().idxmin()}
productos_vendidos_tienda2={"Mas vendido":tienda2['Producto'].value_counts().idxmax(),"Menos vendido":tienda2['Producto'].value_counts().idxmin()}
productos_vendidos_tienda3={"Mas vendido":tienda3['Producto'].value_counts().idxmax(),"Menos vendido":tienda3['Producto'].value_counts().idxmin()}
productos_vendidos_tienda4={"Mas vendido":tienda4['Producto'].value_counts().idxmax(),"Menos vendido":tienda4['Producto'].value_counts().idxmin()}

# %%
#Envio promedio por tienda
envio_promedio_tienda1=tienda['Costo de envío'].mean()
envio_promedio_tienda2=tienda2['Costo de envío'].mean()
envio_promedio_tienda3=tienda3['Costo de envío'].mean()
envio_promedio_tienda4=tienda4['Costo de envío'].mean()

# %% [markdown]
# # Visualizacion

# %%
import matplotlib.pyplot as plt

# %%
#Grafico de barras — Productos más vendidos por tienda
top1 = tienda["Producto"].value_counts().head(5)
top2 = tienda2["Producto"].value_counts().head(5)
top3 = tienda3["Producto"].value_counts().head(5)
top4 = tienda4["Producto"].value_counts().head(5)

plt.figure(figsize=(12,8))

plt.subplot(2,2,1)
plt.bar(top1.index, top1.values)
plt.title("Top productos - Tienda 1")
plt.xticks(rotation=45)

plt.subplot(2,2,2)
plt.bar(top2.index, top2.values)
plt.title("Top productos - Tienda 2")
plt.xticks(rotation=45)

plt.subplot(2,2,3)
plt.bar(top3.index, top3.values)
plt.title("Top productos - Tienda 3")
plt.xticks(rotation=45)

plt.subplot(2,2,4)
plt.bar(top4.index, top4.values)
plt.title("Top productos - Tienda 4")
plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %%
#Grafico de pie — Distribución de categorías
cat1 = tienda["Categoría del Producto"].value_counts()
cat2 = tienda2["Categoría del Producto"].value_counts()
cat3 = tienda3["Categoría del Producto"].value_counts()
cat4 = tienda4["Categoría del Producto"].value_counts()

plt.figure(figsize=(12,8))

plt.subplot(2,2,1)
plt.pie(cat1.values, labels=cat1.index, autopct="%1.1f%%")
plt.title("Categorías - Tienda 1")

plt.subplot(2,2,2)
plt.pie(cat2.values, labels=cat2.index, autopct="%1.1f%%")
plt.title("Categorías - Tienda 2")

plt.subplot(2,2,3)
plt.pie(cat3.values, labels=cat3.index, autopct="%1.1f%%")
plt.title("Categorías - Tienda 3")

plt.subplot(2,2,4)
plt.pie(cat4.values, labels=cat4.index, autopct="%1.1f%%")
plt.title("Categorías - Tienda 4")

plt.tight_layout()
plt.show()

# %%
#Gráfico de líneas — Calificación promedio por categoría

cal1 = tienda.groupby("Categoría del Producto")["Calificación"].mean()
cal2 = tienda2.groupby("Categoría del Producto")["Calificación"].mean()
cal3 = tienda3.groupby("Categoría del Producto")["Calificación"].mean()
cal4 = tienda4.groupby("Categoría del Producto")["Calificación"].mean()

plt.figure(figsize=(12,8))

plt.subplot(2,2,1)
plt.plot(cal1.index, cal1.values, marker='o')
plt.title("Calificación promedio - Tienda 1")
plt.xticks(rotation=45)

plt.subplot(2,2,2)
plt.plot(cal2.index, cal2.values, marker='o')
plt.title("Calificación promedio - Tienda 2")
plt.xticks(rotation=45)

plt.subplot(2,2,3)
plt.plot(cal3.index, cal3.values, marker='o')
plt.title("Calificación promedio - Tienda 3")
plt.xticks(rotation=45)

plt.subplot(2,2,4)
plt.plot(cal4.index, cal4.values, marker='o')
plt.title("Calificación promedio - Tienda 4")
plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %% [markdown]
# # Conclusiones e informe final

# %% [markdown]
# # Informe Final de Análisis de Ventas – Alura Store
#
# ## Introducción
#
# El objetivo de este análisis es evaluar el desempeño de las cuatro tiendas del Sr. Juan para determinar cuál de ellas debería ser vendida. Para ello, se analizaron diferentes factores clave que influyen en el rendimiento de cada tienda, tales como los ingresos totales, las categorías de productos más y menos vendidas, las calificaciones promedio de los clientes, los productos con mayor y menor número de ventas y el coste promedio de envío.
#
# A partir de estos análisis y de las visualizaciones generadas, se busca identificar las fortalezas y debilidades de cada tienda para tomar una decisión estratégica basada en datos.
#
# ---
#
# ## Análisis de los datos
#
# ### Ingresos totales de las tiendas
#
# El análisis de los ingresos totales permitió identificar diferencias en el rendimiento financiero entre las tiendas. Algunas tiendas presentan mayores ingresos, lo que indica una mayor cantidad de ventas o productos de mayor valor.
#
# Las tiendas con mayores ingresos muestran un mejor desempeño comercial, mientras que aquellas con ingresos menores podrían tener menor demanda o estrategias de venta menos efectivas.
#
# ---
#
# ### Categorías de productos más y menos vendidas
#
# El análisis de las categorías de productos permitió identificar cuáles son los tipos de productos más demandados por los clientes. Algunas categorías concentran una mayor cantidad de ventas, lo que indica que son más populares entre los consumidores.
#
# Por otro lado, también se identificaron categorías con menor volumen de ventas, lo que podría indicar menor interés por parte de los clientes o una oferta menos competitiva.
#
# ---
#
# ### Calificaciones promedio de los clientes
#
# Las calificaciones otorgadas por los clientes permiten evaluar el nivel de satisfacción con los productos y servicios ofrecidos por cada tienda.
#
# Las tiendas con calificaciones promedio más altas reflejan una mejor experiencia de compra, lo que puede contribuir a una mayor fidelización de clientes y mejores resultados en ventas. En contraste, calificaciones más bajas pueden indicar problemas relacionados con la calidad de los productos o el servicio.
#
# ---
#
# ### Productos más y menos vendidos
#
# El análisis de los productos más vendidos permitió identificar cuáles son los artículos que generan mayor demanda dentro de cada tienda. Estos productos suelen tener un impacto importante en los ingresos totales.
#
# Asimismo, también se identificaron productos con menor número de ventas, lo cual puede indicar menor interés por parte del mercado o la necesidad de revisar la estrategia de comercialización.
#
# ---
#
# ### Coste de envío promedio
#
# El coste de envío promedio es un factor importante en la decisión de compra de los clientes. Tiendas con costos de envío más elevados pueden resultar menos atractivas para los consumidores.
#
# Por el contrario, tiendas con costes de envío más bajos pueden ofrecer una ventaja competitiva al reducir el costo total de compra.
#
# ---
#
# ## Conclusión
#
# Con base en el análisis realizado, se recomienda que el Sr. Juan considere vender la tienda que presenta el menor rendimiento general en comparación con las demás. Esta decisión se basa en factores como menores ingresos totales, menor volumen de ventas en productos clave, calificaciones promedio más bajas por parte de los clientes o mayores costes de envío.
#
# Vender la tienda con menor desempeño permitiría al Sr. Juan concentrar sus recursos en las tiendas más rentables y con mayor potencial de crecimiento, optimizando así la gestión de su negocio y mejorando su rentabilidad a largo plazo.
